# %% [markdown]
# Simple Plots

# %%
from mpmath import mpf, mp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
mp.dps = 3
# load data
filepath = 'data/roots_30.csv'
roots = pd.read_csv(filepath)

# %%
roots['real']
# Out:
# 0       1.000000
# 1       0.500000
# 2       0.381966
# 3       2.618034
# 4       0.333333
#           ...
# 2351    0.933380
# 2352    0.121744
# 2353    0.121744
# 2354    1.492568
# 2355    1.492568
# Name: real, Length: 2356, dtype: float64

# %%
xstrings = roots['real'].to_numpy()
ystrings = roots['imaginary'].to_numpy()
qstrings = roots['q'].to_numpy()
errorstrings = roots['error'].to_numpy()
xs = []
ys = []
qs = []
es = []
for x in xstrings:
    if x not in roots.columns:
        xs.append(mpf(x))
for y in ystrings:
    if y not in roots.columns:
        ys.append(mpf(y))
for q in qstrings:
    if q not in roots.columns:
        qs.append(mpf(q))
for e in errorstrings:
    if  e not in roots.columns:
        es.append(mpf(e))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-984b5a6e7121> in <module>
#      15 for q in qstrings:
#      16     if q not in roots.columns:
# ---> 17         qs.append(mpf(q))
#      18 for e in errorstrings:
#      19     if  e not in roots.columns:
#
# ~/opt/anaconda3/envs/rutabaga/lib/python3.8/site-packages/mpmath/ctx_mp_python.py in __new__(cls, val, **kwargs)
#      75         else:
#      76             v = new(cls)
# ---> 77             v._mpf_ = mpf_pos(cls.mpf_convert_arg(val, prec, rounding), prec, rounding)
#      78             return v
#      79
#
# ~/opt/anaconda3/envs/rutabaga/lib/python3.8/site-packages/mpmath/ctx_mp_python.py in mpf_convert_arg(cls, x, prec, rounding)
#      94                 return a
#      95             raise ValueError("can only create mpf from zero-width interval")
# ---> 96         raise TypeError("cannot create mpf from " + repr(x))
#      97
#      98     @classmethod
#
# TypeError: cannot create mpf from 3

# %%
fig, axs = plt.subplots(1,figsize=(20,20))
axs.scatter(xs,ys, c=qs, s=5)
