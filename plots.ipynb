# %% [markdown]
# Simple Plots

# %%
from mpmath import mpf, mp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
mp.dps = 100
# load data
filepath = 'data/roots_10.csv'
roots = pd.read_csv(filepath)

# %%
roots
# Out:
#      Unnamed: 0                     real                imaginary   q  \
# 0           NaN                     real                imaginary   q
# 1           0.0   -0.7071067811865475244    0.7071067811865475244   4
# 2           1.0   -0.7071067811865475244   -0.7071067811865475244   4
# 3           2.0    0.7071067811865475244   -0.7071067811865475244   4
# 4           3.0    0.7071067811865475244    0.7071067811865475244   4
# ..          ...                      ...                      ...  ..
# 354       353.0  -0.57394951785239367701  -0.36898940748180408776  12
# 355       354.0  -0.62481053384382658688   0.30024259022012041916  13
# 356       355.0  -0.62481053384382658688  -0.30024259022012041916  13
# 357       356.0   0.62481053384382658688   -1.3002425902201204192  13
# 358       357.0   0.62481053384382658688    1.3002425902201204192  13
#
#                          error
# 0                        error
# 1    1.6940658945086006781e-21
# ...

# %%
xstrings = roots['real'].to_numpy()[1:]
ystrings = roots['imaginary'].to_numpy()[1:]
xs = []
ys = []
for x in xstrings:
    xs.append(mpf(x))
for y in ystrings:
    ys.append(mpf(y))

# %%
plt.scatter(xs,ys, c=c)

# %%
x
# Out:
# array([-7.07106781e-01, -7.07106781e-01,  7.07106781e-01,  7.07106781e-01,
#         1.32471796e+00, -6.62358979e-01, -6.62358979e-01,  5.00000000e-01,
#         5.00000000e-01,  9.20672461e-01,  9.20672461e-01, -6.81926347e-01,
#        -6.81926347e-01, -9.28755837e-01, -9.28755837e-01,  6.04612591e-01,
#         6.04612591e-01,  8.53971326e-02,  8.53971326e-02,  1.01808094e+00,
#         1.01808094e+00, -8.09040749e-01, -8.09040749e-01, -7.03014858e-01,
#        -7.03014858e-01,  6.17010361e-01,  6.17010361e-01, -1.10961180e-01,
#        -1.10961180e-01,  4.87925485e-01,  4.87925485e-01,  9.26031365e-01,
#         9.26031365e-01, -8.14673716e-01, -8.14673716e-01, -6.95181490e-01,
#        -6.95181490e-01,  9.26180179e-01,  9.26180179e-01, -1.05550514e+00,
#        -1.05550514e+00,  6.04608518e-01,  6.04608518e-01,  4.05162384e-01,
#         4.05162384e-01, -2.97851055e-01, -2.97851055e-01,  1.22895036e-03,
# ...
